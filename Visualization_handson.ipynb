# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Cars (1) (1).csv',skipinitialspace=True) # to skip all the extra space from the dataset

# %%
df
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0    14.0          8        350.0  165     4209.0          12  1972      US.
# 1    31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971      US.
# 3    15.0          8        400.0  150     3761.0          10  1971      US.
# 4    30.5          4         98.0   63     2051.0          17  1978      US.
# ..    ...        ...          ...  ...        ...         ...   ...      ...
# 256  17.0          8        305.0  130     3840.0          15  1980      US.
# 257  36.1          4         91.0   60     1800.0          16  1979   Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983      US.
# 259  18.0          6        232.0  100     3288.0          16  1972      US.
# 260  22.0          6        250.0  105     3353.0          15  1977      US.
#
# [261 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %% [markdown]
# # Create scatterplot for the following data, make sure all the plots appear in the same plane with x-label and y-label evenly spaced.
#
# a. Create scatter plots with between (mpg-hp, mpg-weight, hp-mpg, hp-time-to-60) with respect to each brand.

# %%
fig=plt.subplots(2,2,figsize=(20,10))
plt.subplot(2,2,1)
sns.scatterplot(df,x="mpg",y="hp",hue="brand")
plt.title("Mileage vs Power")
plt.subplot(2,2,2)
sns.scatterplot(df,x="mpg",y="weightlbs",hue="brand")
plt.title("Mileage vs Weight of the Cars")
plt.subplot(2,2,3)
sns.scatterplot(df,x="hp",y="mpg",hue="brand")
plt.title("Power vs Mileage")
plt.subplot(2,2,4)
sns.scatterplot(df,x="hp",y="time-to-60",hue="brand")
plt.title("Power vs time")
plt.show()

# %% [markdown]
# # 1.b) create a bar plot for the following make sure all the plots appear in the same plane with x-label and y-label evenly spaced.
#
# *  create a bar plot that show the visual representation of hp, mpg, weight,time-to-60 with respect to to the number of cylinders of the brands.

# %%
fig = plt.subplots(2,2,figsize=(8,10))
plt.subplot(2,2,1)
sns.barplot(df, y='hp', x='cylinders', hue='brand', palette='husl')
plt.subplot(2,2,2)
sns.barplot(df, y='mpg', x='cylinders', hue='brand', palette='hls')
plt.subplot(2,2,3)
sns.barplot(df, y='weightlbs', x='cylinders', hue='brand', palette='viridis')
plt.subplot(2,2,4)
sns.barplot(df, y='time-to-60', x='cylinders', hue='brand', palette='magma')
# Out:
# <Axes: xlabel='cylinders', ylabel='time-to-60'>

# %% [markdown]
# # create a box plot for the following make sure all the plots appear in the same plane with x-label and y-label evenly spaced.

# %% [markdown]
# *   create a bar plot that show the visual representation of hp, mpg, weight,time-to-60 with respect to to the number of cylinders of the brands.

# %%
fig = plt.subplots(2,2,figsize=(8,10))
plt.subplot(2,2,1)
sns.boxplot(df, y='hp', x='cylinders', hue='brand')
plt.subplot(2,2,2)
sns.boxplot(df, y='mpg', x='cylinders', hue='brand')
plt.subplot(2,2,3)
sns.boxplot(df, y='weightlbs', x='cylinders', hue='brand')
plt.subplot(2,2,4)
sns.boxplot(df, y='time-to-60', x='cylinders', hue='brand')
# Out:
# <Axes: xlabel='cylinders', ylabel='time-to-60'>

# %% [markdown]
# # pairplot : Area plot and scatter plot

# %%
sns.pairplot(df,hue='brand')
plt.show()

# %% [markdown]
# # 5. Create a heatmap  for the entire data to study coorelation   between each of the columns:

# %%
x=df.iloc[ : , :-1]
sns.heatmap(x.corr(),annot=True)
plt.show()

# %% [markdown]
# # create a histogram plot for the following make sure all the plots appear in the same plane with x-label and y-label evenly spaced.
#
#
#
# *   create a bar plot that show the visual representation of hp, mpg, weight,time-to-60 with respect to to the number of cylinders of the brands.

# %%
fig = plt.subplots(2,2,figsize=(20,10))
plt.subplot(2,2,1)
sns.histplot(df, x='hp', hue='brand')
plt.subplot(2,2,2)
sns.histplot(df, x='mpg', hue='brand')
plt.subplot(2,2,3)
sns.histplot(df, x='weightlbs', hue='brand')
plt.subplot(2,2,4)
sns.histplot(df, x='time-to-60', hue='brand')
plt.show()

# %% [markdown]
# # Create Doughnut plot to  represent the following:
# a. The cars  are based on the various counts of cylinders.
#
#
#
# Homework.

# %%
count=df['brand'].value_counts()
print(count)
# Out:
# brand
# US.        162
# Japan.      51
# Europe.     48
# Name: count, dtype: int64

# %%
count.plot.pie(autopct='%1.2f')
centre=plt.Circle((0,0),0.50,fc='white')
fig=plt.gcf()
fig=plt.gca().add_artist(centre)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Create the area chart for the following:
# a. mpg with respect to each brand of the car.

# %%
sns.histplot(df,x='mpg',hue='brand',element='poly')# poly is used to convert histplot to are plot
plt.show()

# %%
diamods=sns.load_dataset('diamonds')

# %%
diamods
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# # Q1. how does daimomd carat affect its price?

# %%
sns.scatterplot(x='carat',y='price',data=diamods)
plt.show()

# %% [markdown]
# # Q2. Whitch diamond cut has the highest average price?

# %%
sns.barplot(x='cut',y='price',data=diamods)
plt.show()

# %% [markdown]
# # Q3. how are carat values distributed?

# %%
sns.histplot(diamods['carat'], kde=True)
plt.show()

# %% [markdown]
# # Q4. what is the price range and aslo can find out that there is an outliers or not for each diamond cut?

# %%
sns.boxplot(data=diamods,x="cut",y="price")
plt.show()

# %% [markdown]
# # Q5. which features are most related to diamond price?

# %%
corr=diamods.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# # Q6. how is carat spread across  different cuts?

# %%
sns.violinplot(x='cut',y='carat',data=diamods)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
#load titanic dataset
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # Q1.How many people survived vs didn't survive?

# %%
sns.countplot(data=df,x='survived')
plt.show()

# %% [markdown]
# # 2. which passenger class had the most people onboard?

# %%
sns.countplot(data=df, x='class')
plt.show()

# %% [markdown]
# # 3. was the gender distribution equal on the titanic?

# %%
sns.countplot(data=df,x='sex')
plt.show()
